# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd
# from myUtils import *

# rootPath = "../../results/scenario/geothermal"
# rootPath = "../../results/scenario/biogas"
# rootPath = "../../results/scenario/PHS"
rootPath = "../../results/scenario/PHS"
# rootPath = "../../results/scenario/battery"
import seaborn as sns
plt.style.use('seaborn-v0_8-whitegrid')
sns.color_palette("muted", 14)
# %matplotlib inline

# n = pypsa.Network("../../results/base/base27Node2045/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# nMean = pypsa.Network(rootPath + "-mean/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# nOptimist = pypsa.Network(rootPath + "-optimist/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# n = pypsa.Network(rootPath + "/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")

# n = pypsa.Network("../../results/scenario/h2-best/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# n = pypsa.Network("../../results/scenario/h2-de/postnetworks/base_s_20_lvopt_3H_3H_2045.nc")
# n = pypsa.Network("../../results/scenario-old/h2-idea/postnetworks/base_s_27_lc1_3H_3H_2045.nc")
n = pypsa.Network("./base_s_27_3H_3H_2045.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['AT0 0 coal for industry', 'BE0 0 coal for industry',
#        'CH0 0 coal for industry', 'CZ0 0 coal for industry',
#        'DE0 0 coal for industry', 'DE0 1 coal for industry',
#        'DE0 2 coal for industry', 'DE0 3 coal for industry',
#        'DE0 4 coal for industry', 'DE0 5 coal for industry',
#        'DE0 6 coal for industry', 'DE0 7 coal for industry',
#        'DK0 0 coal for industry', 'DK1 0 coal for industry',
#        'ES0 0 coal for industry', 'ES6 0 coal for industry',
#        'FR0 0 coal for industry', 'FR4 0 coal for industry',
#        'GB2 0 coal for industry', 'GB5 0 coal for industry',
#        'IT0 0 coal for industry', 'IT3 0 coal for industry',
#        'LU0 0 coal for industry', 'NL0 0 coal for industry',
#        'NO1 0 coal for industry', 'PL0 0 coal for industry',
#        'SE1 0 coal for industry'],
#       dtype='object', name='name')
# INFO:pypsa.io:Imported network base_s_27_3H_3H_2045.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.generators.groupby('carrier').count()
# Out:
#                                bus  control  type  p_nom  p_nom_mod  \
# carrier
# biogas                          27       27    27     27         27
# coal                            19       19    19     19         19
# gas                             22       22    22     22         22
# nuclear                          8        8     8      8          8
# offwind-ac                      18       18    18     18         18
# offwind-dc                      14       14    14     14         14
# offwind-float                   18       18    18     18         18
# oil primary                      1        1     1      1          1
# onwind                          27       27    27     27         27
# rural solar thermal             27       27    27     27         27
# solar                           27       27    27     27         27
# solar rooftop                   27       27    27     27         27
# solar-hsat                      27       27    27     27         27
# solid biomass                   54       54    54     54         54
# urban central solar thermal     26       26    26     26         26
# urban decentral solar thermal   27       27    27     27         27
#
#                                p_nom_extendable  p_nom_min  p_nom_max  \
# carrier
# biogas                                       27         27         27
# coal                                         19         19         19
# gas                                          22         22         22
# nuclear                                       8          8          8
# offwind-ac                                   18         18         18
# offwind-dc                                   14         14         14
# offwind-float                                18         18         18
# oil primary                                   1          1          1
# onwind                                       27         27         27
# rural solar thermal                          27         27         27
# solar                                        27         27         27
# solar rooftop                                27         27         27
# solar-hsat                                   27         27         27
# solid biomass                                54         54         54
# urban central solar thermal                  26         26         26
# urban decentral solar thermal                27         27         27
#
#                                p_min_pu  p_max_pu  ...  min_up_time  \
# carrier                                            ...
# biogas                               27        27  ...           27
# coal                                 19        19  ...           19
# gas                                  22        22  ...           22
# nuclear                               8         8  ...            8
# offwind-ac                           18        18  ...           18
# offwind-dc                           14        14  ...           14
# offwind-float                        18        18  ...           18
# oil primary                           1         1  ...            1
# onwind                               27        27  ...           27
# rural solar thermal                  27        27  ...           27
# solar                                27        27  ...           27
# solar rooftop                        27        27  ...           27
# solar-hsat                           27        27  ...           27
# solid biomass                        54        54  ...           54
# urban central solar thermal          26        26  ...           26
# urban decentral solar thermal        27        27  ...           27
#
#                                min_down_time  up_time_before  \
# carrier
# biogas                                    27              27
# coal                                      19              19
# gas                                       22              22
# nuclear                                    8               8
# offwind-ac                                18              18
# offwind-dc                                14              14
# offwind-float                             18              18
# oil primary                                1               1
# onwind                                    27              27
# rural solar thermal                       27              27
# solar                                     27              27
# solar rooftop                             27              27
# solar-hsat                                27              27
# solid biomass                             54              54
# urban central solar thermal               26              26
# urban decentral solar thermal             27              27
#
#                                down_time_before  ramp_limit_up  \
# carrier
# biogas                                       27              0
# coal                                         19              0
# gas                                          22              0
# nuclear                                       8              0
# offwind-ac                                   18              0
# offwind-dc                                   14              0
# offwind-float                                18              0
# oil primary                                   1              0
# onwind                                       27              0
# rural solar thermal                          27              0
# solar                                        27              0
# solar rooftop                                27              0
# solar-hsat                                   27              0
# solid biomass                                54              0
# urban central solar thermal                  26              0
# urban decentral solar thermal                27              0
#
#                                ramp_limit_down  ramp_limit_start_up  \
# carrier
# biogas                                       0                   27
# coal                                         0                   19
# gas                                          0                   22
# nuclear                                      0                    8
# offwind-ac                                   0                   18
# offwind-dc                                   0                   14
# offwind-float                                0                   18
# oil primary                                  0                    1
# onwind                                       0                   27
# rural solar thermal                          0                   27
# solar                                        0                   27
# solar rooftop                                0                   27
# solar-hsat                                   0                   27
# solid biomass                                0                   54
# urban central solar thermal                  0                   26
# urban decentral solar thermal                0                   27
#
#                                ramp_limit_shut_down  weight  p_nom_opt
# carrier
# biogas                                           27      27         27
# coal                                             19      19         19
# gas                                              22      22         22
# nuclear                                           8       8          8
# offwind-ac                                       18      18         18
# offwind-dc                                       14      14         14
# offwind-float                                    18      18         18
# oil primary                                       1       1          1
# onwind                                           27      27         27
# rural solar thermal                              27      27         27
# solar                                            27      27         27
# solar rooftop                                    27      27         27
# solar-hsat                                       27      27         27
# solid biomass                                    54      54         54
# urban central solar thermal                      26      26         26
# urban decentral solar thermal                    27      27         27
#
# [16 rows x 36 columns]
