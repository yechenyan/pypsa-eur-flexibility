# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd
# from myUtils import *

# rootPath = "../../results/scenario/geothermal"
# rootPath = "../../results/scenario/biogas"
# rootPath = "../../results/scenario/PHS"
rootPath = "../../results/scenario/PHS"
# rootPath = "../../results/scenario/battery"
import seaborn as sns
plt.style.use('seaborn-v0_8-whitegrid')
sns.color_palette("muted", 14)
# %matplotlib inline

# n = pypsa.Network("../../results/base/base27Node2045/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# nMean = pypsa.Network(rootPath + "-mean/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# nOptimist = pypsa.Network(rootPath + "-optimist/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# n = pypsa.Network(rootPath + "/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")

# n = pypsa.Network("../../results/scenario/h2-best/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# n = pypsa.Network("../../results/scenario/h2-de/postnetworks/base_s_20_lvopt_3H_3H_2045.nc")
# n = pypsa.Network("../../results/scenario-old/h2-idea/postnetworks/base_s_27_lc1_3H_3H_2045.nc")
n = pypsa.Network("./base_s_27_3H_3H_2045.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['AT0 0 coal for industry', 'BE0 0 coal for industry',
#        'CH0 0 coal for industry', 'CZ0 0 coal for industry',
#        'DE0 0 coal for industry', 'DE0 1 coal for industry',
#        'DE0 2 coal for industry', 'DE0 3 coal for industry',
#        'DE0 4 coal for industry', 'DE0 5 coal for industry',
#        'DE0 6 coal for industry', 'DE0 7 coal for industry',
#        'DK0 0 coal for industry', 'DK1 0 coal for industry',
#        'ES0 0 coal for industry', 'ES6 0 coal for industry',
#        'FR0 0 coal for industry', 'FR4 0 coal for industry',
#        'GB2 0 coal for industry', 'GB5 0 coal for industry',
#        'IT0 0 coal for industry', 'IT3 0 coal for industry',
#        'LU0 0 coal for industry', 'NL0 0 coal for industry',
#        'NO1 0 coal for industry', 'PL0 0 coal for industry',
#        'SE1 0 coal for industry'],
#       dtype='object', name='name')
# INFO:pypsa.io:Imported network base_s_27_3H_3H_2045.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.generators[n.generators['carrier'] == 'coal']
# Out:
#               bus control type         p_nom  p_nom_mod  p_nom_extendable  \
# Generator
# CZ0 0 coal  CZ0 0      PQ         784.965554        0.0             False
# DE0 0 coal  DE0 0      PQ        5284.903922        0.0             False
# DE0 1 coal  DE0 1      PQ          27.650000        0.0             False
# DE0 2 coal  DE0 2      PQ         805.000000        0.0             False
# DE0 3 coal  DE0 3      PQ        2076.939880        0.0             False
# DE0 4 coal  DE0 4      PQ        2270.300000        0.0             False
# DE0 5 coal  DE0 5      PQ        4958.383426        0.0             False
# DE0 6 coal  DE0 6      PQ         777.000000        0.0             False
# DE0 7 coal  DE0 7      PQ        1898.400000        0.0             False
# DK0 0 coal  DK0 0      PQ        1817.885609        0.0             False
# DK1 0 coal  DK1 0      PQ        1266.000000        0.0             False
# ES0 0 coal  ES0 0      PQ        3456.815120        0.0             False
# ES6 0 coal  ES6 0      PQ         239.703609        0.0             False
# FR0 0 coal  FR0 0      PQ        1161.640565        0.0             False
# GB2 0 coal  GB2 0      PQ        2002.447070        0.0             False
# IT0 0 coal  IT0 0      PQ        6141.944005        0.0             False
# IT3 0 coal  IT3 0      PQ        1133.982457        0.0             False
# NL0 0 coal  NL0 0      PQ        6900.994952        0.0             False
# PL0 0 coal  PL0 0      PQ       13595.179594        0.0             False
#
#                p_nom_min  p_nom_max  p_min_pu  p_max_pu  ...  min_up_time  \
# Generator                                                ...
# CZ0 0 coal    784.965554        inf       0.0       1.0  ...            0
# DE0 0 coal   5284.903922        inf       0.0       1.0  ...            0
# DE0 1 coal     27.650000        inf       0.0       1.0  ...            0
# DE0 2 coal    805.000000        inf       0.0       1.0  ...            0
# DE0 3 coal   2076.939880        inf       0.0       1.0  ...            0
# DE0 4 coal   2270.300000        inf       0.0       1.0  ...            0
# DE0 5 coal   4958.383426        inf       0.0       1.0  ...            0
# DE0 6 coal    777.000000        inf       0.0       1.0  ...            0
# DE0 7 coal   1898.400000        inf       0.0       1.0  ...            0
# DK0 0 coal   1817.885609        inf       0.0       1.0  ...            0
# DK1 0 coal   1266.000000        inf       0.0       1.0  ...            0
# ES0 0 coal   3456.815120        inf       0.0       1.0  ...            0
# ES6 0 coal    239.703609        inf       0.0       1.0  ...            0
# FR0 0 coal   1161.640565        inf       0.0       1.0  ...            0
# GB2 0 coal   2002.447070        inf       0.0       1.0  ...            0
# IT0 0 coal   6141.944005        inf       0.0       1.0  ...            0
# IT3 0 coal   1133.982457        inf       0.0       1.0  ...            0
# NL0 0 coal   6900.994952        inf       0.0       1.0  ...            0
# PL0 0 coal  13595.179594        inf       0.0       1.0  ...            0
#
#             min_down_time  up_time_before  down_time_before  ramp_limit_up  \
# Generator
# CZ0 0 coal              0               1                 0            NaN
# DE0 0 coal              0               1                 0            NaN
# DE0 1 coal              0               1                 0            NaN
# DE0 2 coal              0               1                 0            NaN
# DE0 3 coal              0               1                 0            NaN
# DE0 4 coal              0               1                 0            NaN
# DE0 5 coal              0               1                 0            NaN
# DE0 6 coal              0               1                 0            NaN
# DE0 7 coal              0               1                 0            NaN
# DK0 0 coal              0               1                 0            NaN
# DK1 0 coal              0               1                 0            NaN
# ES0 0 coal              0               1                 0            NaN
# ES6 0 coal              0               1                 0            NaN
# FR0 0 coal              0               1                 0            NaN
# GB2 0 coal              0               1                 0            NaN
# IT0 0 coal              0               1                 0            NaN
# IT3 0 coal              0               1                 0            NaN
# NL0 0 coal              0               1                 0            NaN
# PL0 0 coal              0               1                 0            NaN
#
#            ramp_limit_down  ramp_limit_start_up  ramp_limit_shut_down  weight  \
# Generator
# CZ0 0 coal             NaN                  1.0                   1.0     1.0
# DE0 0 coal             NaN                  1.0                   1.0     1.0
# DE0 1 coal             NaN                  1.0                   1.0     1.0
# DE0 2 coal             NaN                  1.0                   1.0     1.0
# DE0 3 coal             NaN                  1.0                   1.0     1.0
# DE0 4 coal             NaN                  1.0                   1.0     1.0
# DE0 5 coal             NaN                  1.0                   1.0     1.0
# DE0 6 coal             NaN                  1.0                   1.0     1.0
# DE0 7 coal             NaN                  1.0                   1.0     1.0
# DK0 0 coal             NaN                  1.0                   1.0     1.0
# DK1 0 coal             NaN                  1.0                   1.0     1.0
# ES0 0 coal             NaN                  1.0                   1.0     1.0
# ES6 0 coal             NaN                  1.0                   1.0     1.0
# FR0 0 coal             NaN                  1.0                   1.0     1.0
# GB2 0 coal             NaN                  1.0                   1.0     1.0
# IT0 0 coal             NaN                  1.0                   1.0     1.0
# IT3 0 coal             NaN                  1.0                   1.0     1.0
# NL0 0 coal             NaN                  1.0                   1.0     1.0
# PL0 0 coal             NaN                  1.0                   1.0     1.0
#
#             p_nom_opt
# Generator
# CZ0 0 coal        0.0
# DE0 0 coal        0.0
# DE0 1 coal        0.0
# DE0 2 coal        0.0
# DE0 3 coal        0.0
# DE0 4 coal        0.0
# DE0 5 coal        0.0
# DE0 6 coal        0.0
# DE0 7 coal        0.0
# DK0 0 coal        0.0
# DK1 0 coal        0.0
# ES0 0 coal        0.0
# ES6 0 coal        0.0
# FR0 0 coal        0.0
# GB2 0 coal        0.0
# IT0 0 coal        0.0
# IT3 0 coal        0.0
# NL0 0 coal        0.0
# PL0 0 coal        0.0
#
# [19 rows x 37 columns]
