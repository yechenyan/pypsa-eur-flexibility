# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd

n = pypsa.Network("../../../results/scenario/warm_best/networks/base_s_27_3H_3H_2045.nc")
# Out:
# INFO:pypsa.io:Imported network base_s_27_3H_3H_2045.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.carriers
# Out:
#                                      co2_emissions    color  \
# Carrier
# DC                                             0.0  #8a1caf
# AC                                             0.0  #70af1d
# nuclear                                        0.0  #ff8c00
# hydro                                          0.0  #298c81
# onwind                                         0.0  #235ebc
# ...                                            ...      ...
# rural water tanks discharger                   0.0  #e69487
# methanolisation                                0.0  #00FFBF
# urban central CHP                              0.0  #8a5751
# urban decentral water tanks charger            0.0  #e69487
# solar rooftop                                  0.0  #ffea80
#
#                                                                nice_name  \
# Carrier
# DC                                                                    DC
# AC                                                                    AC
# ...

# %%
import init as PeaModule
import importlib

# %load_ext autoreload
# %autoreload 2

Pea = PeaModule.Pea

pea = Pea(n, config= {
  'resolution': 3
})

ac = pea.get(['H2 Store', 'OCGT'])
ac.t('p', multiPUse='p1')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 3333
# ['DE0 0 OCGT', 'DE0 1 OCGT', 'DE0 2 OCGT', 'DE0 3 OCGT', 'DE0 4 OCGT', 'DE0 5 OCGT', 'DE0 6 OCGT', 'DE0 7 OCGT']
# 3333
# ['DE0 3 H2 Store', 'DE0 4 H2 Store', 'DE0 6 H2 Store', 'DE0 0 H2 Store', 'DE0 1 H2 Store', 'DE0 2 H2 Store', 'DE0 5 H2 Store', 'DE0 7 H2 Store']
#                       DE0 0 OCGT  DE0 1 OCGT   DE0 2 OCGT  DE0 3 OCGT  \
# snapshot
# 2019-01-01 00:00:00    -0.000616   -0.000262    -0.000549   -0.000177
# 2019-01-01 03:00:00    -0.000674   -0.000260    -0.000640   -0.000177
# 2019-01-01 06:00:00    -0.000674   -0.000266    -0.000528   -0.000177
# 2019-01-01 09:00:00    -0.000251   -0.000219    -0.000241   -0.000202
# 2019-01-01 12:00:00    -0.000255   -0.000220    -0.000243   -0.000202
# ...                          ...         ...          ...         ...
# 2019-12-31 09:00:00    -0.000271   -0.000243    -0.000262   -0.000225
# ...
