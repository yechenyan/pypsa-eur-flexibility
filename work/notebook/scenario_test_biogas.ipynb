# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd
from utils import *

# rootPath = "../../results/scenario/geothermal"
rootPath = "../../results/scenario/biogas"
# rootPath = "../../results/scenario/PHS"

# %matplotlib inline

n = pypsa.Network(rootPath + "/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# Out:
# INFO:pypsa.io:Imported network base_s_27_lvopt_3H_3H_2045.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.links.loc['DE0 0 biogas to gas']
# Out:
# bus0                         DE0 0 biogas
# bus1                            DE0 0 gas
# type
# carrier                     biogas to gas
# efficiency                        1.00000
# active                               True
# build_year                              0
# lifetime                         21.00000
# p_nom                             0.00000
# p_nom_mod                         0.00000
# p_nom_extendable                     True
# p_nom_min                         0.00000
# p_nom_max                             inf
# p_set                             0.00000
# p_min_pu                          0.00000
# p_max_pu                          1.00000
# capital_cost                      1.00000
# marginal_cost                     0.01042
# marginal_cost_quadratic           0.00000
# stand_by_cost                     0.00000
# length                            0.00000
# terrain_factor                    1.00000
# committable                         False
# ...

# %%
n.links_t.p1['DE0 0 biogas to gas'].plot(figsize=(15,3))
# Out:
# <Axes: xlabel='snapshot'>

# %%
n.links_t.p1['DE0 0 biogas to gas'].sum() * 3 / 1e6
# Out:
# -5.731502972151695

# %%
n.generators_t.p['DE0 0 biogas'].plot()
# Out:
# <Axes: xlabel='snapshot'>

# %%
n.statistics.supply(groupby="de_biogas_generator_grouper")
# Out:
# component
# Generator  DE0 0 biogas   5731502.97215
#            DE0 1 biogas   1158490.59776
#            DE0 2 biogas   2453976.52005
#            DE0 3 biogas   1980501.68836
#            DE0 4 biogas   3521801.81783
#            DE0 5 biogas   8361152.29314
#            DE0 6 biogas   5265827.97480
#            DE0 7 biogas   2147399.47516
# dtype: float64

# %%
n.statistics.supply(groupby="de_biogas_generator_grouper").sum()
# Out:
# 30620653.33925
