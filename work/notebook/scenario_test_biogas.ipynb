# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd
from utils import *

# rootPath = "../../results/scenario/geothermal"
# rootPath = "../../results/scenario/biogas"
rootPath = "../../results/scenario/PHS"

# %matplotlib inline

n = pypsa.Network(rootPath + "-mean/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# Out:
# INFO:pypsa.io:Imported network base_s_27_lvopt_3H_3H_2045.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.storage_units.loc['DE0 0 PHS']
# Out:
# bus                                         DE0 0
# control                                        PQ
# type
# p_nom                                   340.00000
# p_nom_mod                                 0.00000
# p_nom_extendable                            False
# p_nom_min                                 0.00000
# p_nom_max                                     inf
# p_min_pu                                 -1.00000
# p_max_pu                                  1.00000
# p_set                                     0.00000
# q_set                                     0.00000
# sign                                      1.00000
# carrier                                       PHS
# spill_cost                                0.00000
# marginal_cost                             0.00993
# marginal_cost_quadratic                   0.00000
# marginal_cost_storage                     0.00000
# capital_cost                         162299.48673
# active                                       True
# ...

# %%
n.storage_units_t.state_of_charge['DE0 0 PHS'].plot(figsize=(100,3))
# Out:
# <Axes: xlabel='snapshot'>

# %%
1
# Out:
# 1

# %%
n.carriers.loc['PHS']
# Out:
# co2_emissions                       0.00000
# color                               #51dbcc
# nice_name              Pumped Hydro Storage
# max_growth                              inf
# max_relative_growth                 0.00000
# Name: PHS, dtype: object

# %%
n.links_t.p1['TYNDP2020_1'].plot(figsize=(15,3))
# Out:
# <Axes: xlabel='snapshot'>
