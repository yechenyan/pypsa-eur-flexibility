# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd

# rootPath = "../../results/base27Node2045"
rootPath = "../../results/scenario/geothermal"


plt.style.use('bmh')
# %matplotlib inline

n = pypsa.Network(rootPath + "/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# Out:
# INFO:pypsa.io:Imported network base_s_27_lvopt_3H_3H_2045.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
def new_grouper(n, c):
  return n.df(c).index.to_series()

n.s

# %%
n.objective / 1e9
# Out:
# 522.7325723980724

# %%
df = pd.read_csv(rootPath + "/csvs/costs.csv", skiprows=7, header=None)

n.objective
# Out:
# 522732572398.07245

# %%
import pypsa

pd.set_option('display.width', 100000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


def de_grouper(n, c):
  df = n.df(c)
  specific_indices = ['10', '13', '14', '16', '17', '18', '19', '23', '24', '25','26', '28', '29', '3', '30', '31', '32', '33', '34', '35', '36', '37','4', '5']
  indexs = df[df.index.astype(str).str.contains('DE0') | df.index.astype(str).isin(specific_indices)].index.to_series()
  # n.df(c).index.to_series()
  return indexs
pypsa.statistics.groupers.add_grouper("de_grouper", de_grouper)

def eu_grouper(n, c):
  df = n.df(c)
  indexs = df[df.index.astype(str).str.contains('EU')].index.to_series()
  return indexs
pypsa.statistics.groupers.add_grouper("eu_grouper", eu_grouper)


# print(n.statistics.capex(groupby="new_grouper").sum() / 1e9)

# print(n.statistics.opex(groupby="new_grouper").sum() / 1e9)

print(n.statistics.expanded_capex(groupby="de_grouper").sum() / 1e9)
# print(n.statistics.expanded_capex().sum() / 1e9)

n.statistics.transmission(groupby=["carrier","de_grouper"] ).sum()
# Out:
# 36.61302250898738
# 99014124.26165

# %%
# 成本

df = pd.read_csv(rootPath + "/csvs/nodal_costs.csv", skiprows=7, header=None)

print('total EU:', df[4].sum()/1e9)

filtered_df = df[df[2].isin(['DE0 0', 'DE0 1', 'DE0 2', 'DE0 3', 'DE0 4', 'DE0 5', 'DE0 6', 'DE0 7'])]

print('total DE:', filtered_df[4].sum()/1e9)

pd.set_option('display.float_format', '{:.4f}'.format)
pd.set_option('display.max_rows', None)


filtered_df.groupby(3)[4].sum()/1e6 # M EUR
# Out:
# total EU: 670.0127581246344
# total DE: 53.81659545627004
# 3
# BEV charger                                  1.5999
# DAC                                        132.7799
# EV battery                                   0.0000
# Fischer-Tropsch                            642.6110
# H2 Electrolysis                           3312.8955
# H2 Fuel Cell                                 0.0012
# H2 Store                                   120.9603
# OCGT                                         0.0015
# PHS                                       1375.0512
# SMR                                          0.0013
# SMR CC                                       0.0016
# Sabatier                                     0.0009
# V2G                                          0.0518
# battery                                      0.0021
# battery charger                              0.0031
# battery discharger                           0.0000
# electricity distribution grid             5312.3306
# geothermal district heat                     0.0011
# geothermal heat                              0.0233
# geothermal organic rankine cycle             0.0015
# home battery                                 0.0019
# home battery charger                         0.0032
# home battery discharger                      0.0000
# hydro                                       52.9084
# methanolisation                              0.1567
# nuclear                                   3441.5300
# offwind-ac                                 281.4760
# offwind-dc                                1481.8306
# offwind-float                              136.1793
# onwind                                   17064.2789
# ror                                        833.0956
# rural air heat pump                          0.0060
# rural biomass boiler                       143.5994
# rural gas boiler                            84.4767
# rural ground heat pump                    4160.8564
# rural resistive heater                     172.7991
# rural solar thermal                          0.0007
# rural water tanks                           68.6149
# rural water tanks charger                    0.0611
# rural water tanks discharger                 0.0536
# solar                                     3040.1600
# solar rooftop                                0.0188
# solar-hsat                                   0.0055
# urban central CHP                            0.0021
# urban central CHP CC                         0.0016
# urban central air heat pump               3596.0399
# urban central gas boiler                   303.5324
# urban central resistive heater             186.6417
# urban central solar thermal                  0.0007
# urban central solid biomass CHP              0.0031
# urban central solid biomass CHP CC           0.0394
# urban central water tanks                  907.7574
# urban central water tanks charger            0.7106
# urban central water tanks discharger         0.6597
# urban decentral air heat pump             4788.0992
# urban decentral biomass boiler            1634.0650
# urban decentral gas boiler                  74.2746
# urban decentral resistive heater           359.4976
# urban decentral solar thermal                0.0007
# urban decentral water tanks                104.5730
# urban decentral water tanks charger          0.1462
# urban decentral water tanks discharger       0.1197
# Name: 4, dtype: float64

# %%
# n.explore(components= "Bus", popup = False, tiles= "CartoDB Positron")

# %%
# energy supply

df = pd.read_csv(rootPath + "/csvs/nodal_supply_energy.csv", skiprows=4, header=None)


filtered_df = df #df[df[2].isin(['DE0 0', 'DE0 1', 'DE0 2', 'DE0 3', 'DE0 4', 'DE0 5', 'DE0 6', 'DE0 7'])]

print('total DE', filtered_df[4].sum()/1e9)

pd.set_option('display.float_format', '{:.4f}'.format)
pd.set_option('display.max_rows', None)

filtered_df.groupby(3)[4].sum() # MW
# Out:
# total DE 4.2224526405334474e-11
# 3
# AC0                                         -62209981.6236
# AC1                                          52630623.5986
# BEV charger0                               -809919993.4905
# BEV charger1                                728927994.1414
# DAC0                                       -133863233.5915
# DAC1                                       -340742776.4146
# DAC2                                       -243387697.4390
# DAC3                                        243387697.4390
# DC0                                       -1133989678.2066
# DC1                                        1087719940.4728
# EV battery                                          0.0003
# Fischer-Tropsch0                          -1626955632.2149
# Fischer-Tropsch1                           1299937550.1397
# Fischer-Tropsch2                           -334213944.1409
# Fischer-Tropsch3                             61417560.3422
# H2 Electrolysis0                          -3735262786.7872
# H2 Electrolysis1                           2194093360.9588
# H2 Electrolysis2                            235583026.3404
# H2 Fuel Cell0                                     -40.4104
# H2 Fuel Cell1                                      20.2052
# H2 Fuel Cell2                                       4.2299
# H2 Store                                            0.0000
# H2 for industry                            -131820000.0000
# H2 pipeline0                               -452221694.3401
# H2 pipeline1                                452221694.3401
# H2 pipeline2                                 -3875369.5872
# OCGT0                                             -56.8939
# OCGT1                                              23.0420
# OCGT2                                              11.2650
# PHS                                         -20054367.3544
# SMR CC0                                          -147.7938
# SMR CC1                                           101.9777
# SMR CC2                                             2.9263
# SMR CC3                                            26.3369
# SMR0                                              -90.8073
# SMR1                                               69.0135
# SMR2                                               17.9798
# Sabatier0                                        -197.9256
# Sabatier1                                         158.3405
# Sabatier2                                         -31.3514
# Sabatier3                                           6.8887
# V2G0                                        -35215810.4474
# V2G1                                         31694229.4027
# agriculture electricity                     -32071924.7336
# agriculture heat                           -183465446.1550
# agriculture machinery oil                   -87234100.9566
# agriculture machinery oil0                  -87234100.9566
# agriculture machinery oil1                   87234100.9566
# agriculture machinery oil2                   22427887.3559
# battery                                             0.0000
# battery charger0                                -1457.4356
# battery charger1                                 1424.2658
# battery discharger0                             -1424.2659
# battery discharger1                              1391.8510
# biogas                                      282941365.5260
# biogas to gas0                             -282941365.5260
# biogas to gas1                              282941365.5260
# biogas to gas2                              -56022390.3741
# co2                                                -0.0013
# co2 sequestered                            -199999999.9999
# co2 sequestered0                           -199999999.9999
# co2 sequestered1                            199999999.9999
# co2 stored                                          0.0000
# coal                                         24861680.0000
# coal for industry                           -24861680.0000
# coal for industry0                          -24861680.0000
# coal for industry1                           24861680.0000
# coal for industry2                            8356010.6480
# electricity                                 401164304.3734
# electricity distribution grid0            -2916437180.7457
# electricity distribution grid1             2828944065.3233
# gas                                          46600582.0831
# gas for industry                           -273030000.0000
# gas for industry CC0                       -303366651.7159
# gas for industry CC1                        273029986.5443
# gas for industry CC2                          6006659.7040
# gas for industry CC3                         54059937.3358
# gas for industry0                                 -13.4559
# gas for industry1                                  13.4559
# gas for industry2                                   2.6643
# geothermal district heat0                         -14.6095
# geothermal district heat1                          11.6876
# geothermal heat                                    24.1235
# geothermal heat0                                  -24.1222
# geothermal heat1                                   23.9025
# geothermal organic rankine cycle0                  -9.2607
# geothermal organic rankine cycle1                   9.2607
# home battery                                        0.0001
# home battery charger0                           -1016.8579
# home battery charger1                             993.7152
# home battery discharger0                         -993.7153
# home battery discharger1                          971.0993
# hydro                                       267724854.5129
# industry electricity                      -1446830000.0000
# industry methanol                            -8140000.0000
# industry methanol0                           -8140000.0000
# industry methanol1                            8140000.0000
# industry methanol2                            2018799.1369
# kerosene for aviation                      -667018465.4838
# kerosene for aviation0                     -667018465.4842
# kerosene for aviation1                      667018465.4842
# kerosene for aviation2                      171490447.4760
# land transport EV                          -693712183.6942
# land transport oil                         -396650195.8454
# land transport oil0                        -396650195.8454
# land transport oil1                         396650195.8454
# land transport oil2                         101978765.3519
# low-temperature heat for industry           -59920000.0000
# methanol                                           -0.0000
# methanolisation0                           -435317661.4147
# methanolisation1                            382513629.0851
# methanolisation2                           -103642568.9124
# methanolisation3                            -94867098.8034
# methanolisation4                              9563192.9347
# naphtha for industry                       -344400000.0000
# naphtha for industry0                      -344400000.0004
# naphtha for industry1                       344400000.0004
# naphtha for industry2                        76015240.0001
# naphtha for industry3                        12530000.0000
# nuclear                                     484477447.8865
# offwind-ac                                   80117222.0489
# offwind-dc                                   39023858.1865
# offwind-float                                11429777.9212
# oil                                                 0.0000
# oil primary                                 285791809.0213
# oil refining0                              -285791809.0213
# oil refining1                               271341036.8810
# oil refining2                                 3715293.5173
# onwind                                     5573475543.5578
# process emissions                           108940000.0000
# process emissions CC0                      -121469998.7216
# process emissions CC1                        12146999.8722
# process emissions CC2                       109322998.8495
# process emissions0                                 -1.2787
# process emissions1                                  1.2787
# ror                                         115841675.7110
# rural air heat pump0                             -275.8911
# rural air heat pump1                              734.4330
# rural biomass boiler0                        -8432745.3183
# rural biomass boiler1                         7083506.0674
# rural gas boiler0                             -818831.2015
# rural gas boiler1                              798360.4214
# rural gas boiler2                              162128.5779
# rural ground heat pump0                    -170929526.4712
# rural ground heat pump1                     596315299.4571
# rural heat                                 -450120182.4677
# rural resistive heater0                     -35958633.9997
# rural resistive heater1                      32362770.5997
# rural solar thermal                                27.3350
# rural water tanks                            -2545381.7804
# rural water tanks charger0                  -22658795.4500
# rural water tanks charger1                   22429941.6160
# rural water tanks discharger0               -19884559.8356
# rural water tanks discharger1                19683725.7813
# shipping methanol                          -374373629.0814
# shipping methanol0                         -374373629.0817
# shipping methanol1                          374373629.0817
# shipping methanol2                           92848299.6656
# shipping oil                                -75975824.7253
# shipping oil0                               -75975824.7254
# shipping oil1                                75975824.7254
# shipping oil2                                19533384.5369
# solar                                       107839176.4901
# solar rooftop                                53390321.6992
# solar-hsat                                  271270439.6474
# solid biomass                               739951947.4589
# solid biomass for industry                 -561460000.0000
# solid biomass for industry CC0             -623844440.2819
# solid biomass for industry CC1              561459996.2537
# solid biomass for industry CC2             -205887380.6262
# solid biomass for industry CC3              205887380.6262
# solid biomass for industry0                        -3.7460
# solid biomass for industry1                         3.7460
# urban central CHP CC0                             -50.0295
# urban central CHP CC1                              18.9742
# urban central CHP CC2                              22.2604
# urban central CHP CC3                               0.9906
# urban central CHP CC4                               8.9153
# urban central CHP0                           -2482164.8947
# urban central CHP1                            1005276.7824
# urban central CHP2                            1025792.6351
# urban central CHP3                             491468.6492
# urban central air heat pump0               -273326182.5625
# urban central air heat pump1                916550472.9541
# urban central gas boiler0                   -22347552.6944
# urban central gas boiler1                    23129717.0387
# urban central gas boiler2                     4424815.4335
# urban central heat                         -973474649.6733
# urban central resistive heater0            -117955112.4421
# urban central resistive heater1             116775561.3177
# urban central solar thermal                        67.1056
# urban central solid biomass CHP CC0         -49762217.9573
# urban central solid biomass CHP CC1          11033726.8255
# urban central solid biomass CHP CC2          41053829.8148
# urban central solid biomass CHP CC3         -16423024.7924
# urban central solid biomass CHP CC4          16423024.7924
# urban central solid biomass CHP0                 -191.2809
# urban central solid biomass CHP1                   51.5311
# urban central solid biomass CHP2                  157.8068
# urban central water tanks                   -14768116.6765
# urban central water tanks charger0         -826623700.5761
# urban central water tanks charger1          818274801.2003
# urban central water tanks discharger0      -803506684.5238
# urban central water tanks discharger1       795391267.0101
# urban decentral air heat pump0             -268114581.8313
# urban decentral air heat pump1              666908553.8454
# urban decentral biomass boiler0             -57912348.8796
# urban decentral biomass boiler1              48646373.0589
# urban decentral gas boiler0                   -526546.4793
# urban decentral gas boiler1                    513382.8173
# urban decentral gas boiler2                    104256.2029
# urban decentral heat                       -845821637.4320
# urban decentral resistive heater0          -154341097.8867
# urban decentral resistive heater1           138906988.0980
# urban decentral solar thermal                      33.3091
# urban decentral water tanks                  -7729484.9525
# urban decentral water tanks charger0        -61291712.5494
# urban decentral water tanks charger1         60672666.2526
# urban decentral water tanks discharger0     -52943181.3002
# urban decentral water tanks discharger1      52408455.1690
# Name: 4, dtype: float64

# %%
def calculate_energy(n):

    for c in n.iterate_components(n.one_port_components | n.branch_components):
        if c.name in n.one_port_components:
            c_energies = (
                c.pnl.p.multiply(n.snapshot_weightings.generators, axis=0)
                .sum()
                .multiply(c.df.sign)
                .groupby(c.df.carrier)
                .sum()
            )
        else:
            c_energies = pd.Series(0.0, c.df.carrier.unique())
            for port in [col[3:] for col in c.df.columns if col[:3] == "bus"]:
                totals = (
                    c.pnl["p" + port]
                    .multiply(n.snapshot_weightings.generators, axis=0)
                    .sum()
                )
                # remove values where bus is missing (bug in nomopyomo)
                no_bus = c.df.index[c.df["bus" + port] == ""]
                totals.loc[no_bus] = float(
                    n.component_attrs[c.name].loc["p" + port, "default"]
                )
                c_energies -= totals.groupby(c.df.carrier).sum()

        c_energies = pd.concat([c_energies], keys=[c.list_name])
        return c_energies

energy = calculate_energy(n)

print(len(energy))
# Out:
# 21

# %%
def calculate_supply_energy(n, label, supply_energy):
    """
    Calculate the total energy supply/consuption of each component at the buses
    aggregated by carrier.
    """
    bus_carriers = n.buses.carrier.unique()

    for i in bus_carriers:
        bus_map = n.buses.carrier == i
        bus_map.at[""] = False

        for c in n.iterate_components(n.one_port_components):
            items = c.df.index[c.df.bus.map(bus_map).fillna(False)]
            items = [element for element in items if 'DE0' in element]

            if len(items) == 0:
                continue

            s = (
                c.pnl.p[items]
                .multiply(n.snapshot_weightings.generators, axis=0)
                .sum()
                .multiply(c.df.loc[items, "sign"])
                .groupby(c.df.loc[items, "carrier"])
                .sum()
            )
            s = pd.concat([s], keys=[c.list_name])
            s = pd.concat([s], keys=[i])

            supply_energy = supply_energy.reindex(s.index.union(supply_energy.index))
            supply_energy.loc[s.index, label] = s

        for c in n.iterate_components(n.branch_components):
            for end in [col[3:] for col in c.df.columns if col[:3] == "bus"]:
                items = c.df.index[c.df[f"bus{str(end)}"].map(bus_map).fillna(False)]
                items = [element for element in items if 'DE0' in element]
                if len(items) == 0:
                    continue

                s = (-1) * c.pnl["p" + end][items].multiply(
                    n.snapshot_weightings.generators, axis=0
                ).sum().groupby(c.df.loc[items, "carrier"]).sum()
                s.index = s.index + end
                s = pd.concat([s], keys=[c.list_name])
                s = pd.concat([s], keys=[i])

                supply_energy = supply_energy.reindex(
                    s.index.union(supply_energy.index)
                )

                supply_energy.loc[s.index, label] = s

    return supply_energy

columns = pd.MultiIndex.from_tuples(
        [(27, 'vopt', '3H3H', 2045)],
        names=["cluster", "ll", "opt", "planning_horizon"],
    )

supply_energy = pd.DataFrame(columns=columns, dtype=float)

# calculate_supply_energy(n, (27, 'vopt', '3H3H', 2045), supply_energy)

# %%
n.controllable_one_port_components
# Out:
# {'Generator', 'Load', 'StorageUnit', 'Store'}

# %%
opt_name = {"Store": "e", "Line": "s", "Transformer": "s"}

def calculate_costs(n, label, costs):
    for c in n.iterate_components(
        n.branch_components | n.controllable_one_port_components ^ {"Load"}
    ):
        capital_costs = c.df.capital_cost * c.df[opt_name.get(c.name, "p") + "_nom_opt"]
        capital_costs_grouped = capital_costs.groupby(c.df.carrier).sum()

        capital_costs_grouped = pd.concat([capital_costs_grouped], keys=["capital"])
        capital_costs_grouped = pd.concat([capital_costs_grouped], keys=[c.list_name])

        costs = costs.reindex(capital_costs_grouped.index.union(costs.index))

        costs.loc[capital_costs_grouped.index, label] = capital_costs_grouped

        if c.name == "Link":
            p = c.pnl.p0.multiply(n.snapshot_weightings.generators, axis=0).sum()
        elif c.name == "Line":
            continue
        elif c.name == "StorageUnit":
            p_all = c.pnl.p.multiply(n.snapshot_weightings.generators, axis=0)
            p_all[p_all < 0.0] = 0.0
            p = p_all.sum()
        else:
            p = c.pnl.p.multiply(n.snapshot_weightings.generators, axis=0).sum()

        # correct sequestration cost
        if c.name == "Store":
            items = c.df.index[
                (c.df.carrier == "co2 stored") & (c.df.marginal_cost <= -100.0)
            ]
            c.df.loc[items, "marginal_cost"] = -20.0

        marginal_costs = p * c.df.marginal_cost

        marginal_costs_grouped = marginal_costs.groupby(c.df.carrier).sum()

        marginal_costs_grouped = pd.concat([marginal_costs_grouped], keys=["marginal"])
        marginal_costs_grouped = pd.concat([marginal_costs_grouped], keys=[c.list_name])

        costs = costs.reindex(marginal_costs_grouped.index.union(costs.index))

        costs.loc[marginal_costs_grouped.index, label] = marginal_costs_grouped
    return costs

columns = pd.MultiIndex.from_tuples(
        [(27, 'vopt', '3H3H', 2045)],
        names=["cluster", "ll", "opt", "planning_horizon"],
    )

supply_energy = pd.DataFrame(columns=columns, dtype=float)

def assign_carriers(n):
    if "carrier" not in n.lines:
        n.lines["carrier"] = "AC"


def assign_locations(n):
    for c in n.iterate_components(n.one_port_components | n.branch_components):
        ifind = pd.Series(c.df.index.str.find(" ", start=4), c.df.index)
        for i in ifind.unique():
            names = ifind.index[ifind == i]
            c.df.loc[names, "location"] = "" if i == -1 else names.str[:i]

# assign_locations(n)
# assign_carriers(n)

calculate_costs(n, (27, 'vopt', '3H3H', 2045), supply_energy)
# Out:
#                                                                            bus0  \
# Link
# relation/10377412-320-DC                                                  FR0 0
# relation/13295785-515-DC                                                  NO1 0
# relation/14126301-450-DC                                                  GB2 0
# relation/15772117-320-DC                                                  GB2 0
# relation/15781671-525-DC                                                  GB2 0
# relation/16213216-525-DC                                                  DE0 0
# relation/17631956-250-DC                                                  ES0 0
# relation/2127794-270-DC                                                   GB2 0
# relation/2505320-400-DC                                                   DK1 0
# relation/3391794-200-DC                                                   IT3 0
# relation/3391931-350-DC                                                   DK0 0
# relation/3392010-450-DC                                                   PL0 0
# relation/3918230-450-DC                                                   DE0 0
# relation/5487095-400-DC                                                   DK0 0
# relation/6914309-500-DC                                                   GB5 0
# relation/8184629-300-DC                                                   DK0 0
# relation/8184632-500-DC                                                   DK0 0
# relation/8185420-320-DC                                                   DK0 0
# relation/8185487-400-DC                                                   GB2 0
# relation/8185711-500-DC                                                   IT3 0
# relation/8193755-320-DC                                                   BE0 0
# relation/9934065-320-DC                                                   FR0 0
# relation/9934066-320-DC                                                   FR0 0
# relation/9965201-450-DC                                                   NL0 0
# relation/9982798-200-DC                                                   FR4 0
# TYNDP2020_1                                                               DE0 0
# TYNDP2020_2                                                               DE0 0
# TYNDP2020_7                                                               GB2 0
# TYNDP2020_10                                                              DE0 4
# TYNDP2020_22                                                              DE0 0
# TYNDP2020_23                                                              DE0 5
# TYNDP2020_29                                                              IT3 0
# TYNDP2020_30                                                              FR4 0
# TYNDP2020_32                                                              GB2 0
# TYNDP2020_36                                                              GB2 0
# TYNDP2020_37                                                              IT0 0
# TYNDP2020_38                                                              SE1 0
# DC25                                                                      DE0 0
# DC34                                                                      DE0 5
# DC35                                                                      DE0 5
# DC40                                                                      DE0 5
# DC40plus                                                                  DE0 5
# DC41                                                                      DE0 5
# DC42                                                                      DE0 0
# DC42plus                                                                  DE0 0
# DC2                                                                       DE0 4
# DC3                                                                       DE0 0
# DC5                                                                       DE0 0
# DC20                                                                      DE0 0
# TYNDP2018_154                                                             GB2 0
# TYNDP2018_25                                                              FR0 0
# TYNDP2018_285                                                             GB2 0
# TYNDP2018_190                                                             NO1 0
# TYNDP2018_16                                                              ES0 0
# TYNDP2018_21                                                              IT0 0
# TYNDP2024_1169                                                            IT3 0
# TYNDP2024_1229                                                            DE0 5
# co2 sequestered                                                      co2 stored
# AT0 0 OCGT                                                               EU gas
# BE0 0 OCGT                                                               EU gas
# CH0 0 OCGT                                                               EU gas
# CZ0 0 OCGT                                                               EU gas
# DE0 0 OCGT                                                               EU gas
# DE0 1 OCGT                                                               EU gas
# DE0 2 OCGT                                                               EU gas
# DE0 3 OCGT                                                               EU gas
# DE0 4 OCGT                                                               EU gas
# DE0 5 OCGT                                                               EU gas
# DE0 6 OCGT                                                               EU gas
# DE0 7 OCGT                                                               EU gas
# DK0 0 OCGT                                                               EU gas
# DK1 0 OCGT                                                               EU gas
# ES0 0 OCGT                                                               EU gas
# ES6 0 OCGT                                                               EU gas
# FR0 0 OCGT                                                               EU gas
# FR4 0 OCGT                                                               EU gas
# GB2 0 OCGT                                                               EU gas
# GB5 0 OCGT                                                               EU gas
# IT0 0 OCGT                                                               EU gas
# IT3 0 OCGT                                                               EU gas
# LU0 0 OCGT                                                               EU gas
# NL0 0 OCGT                                                               EU gas
# NO1 0 OCGT                                                               EU gas
# PL0 0 OCGT                                                               EU gas
# SE1 0 OCGT                                                               EU gas
# AT0 0 H2 Electrolysis                                                     AT0 0
# BE0 0 H2 Electrolysis                                                     BE0 0
# CH0 0 H2 Electrolysis                                                     CH0 0
# CZ0 0 H2 Electrolysis                                                     CZ0 0
# DE0 0 H2 Electrolysis                                                     DE0 0
# DE0 1 H2 Electrolysis                                                     DE0 1
# DE0 2 H2 Electrolysis                                                     DE0 2
# DE0 3 H2 Electrolysis                                                     DE0 3
# DE0 4 H2 Electrolysis                                                     DE0 4
# DE0 5 H2 Electrolysis                                                     DE0 5
# DE0 6 H2 Electrolysis                                                     DE0 6
# DE0 7 H2 Electrolysis                                                     DE0 7
# DK0 0 H2 Electrolysis                                                     DK0 0
# DK1 0 H2 Electrolysis                                                     DK1 0
# ES0 0 H2 Electrolysis                                                     ES0 0
# ES6 0 H2 Electrolysis                                                     ES6 0
# FR0 0 H2 Electrolysis                                                     FR0 0
# FR4 0 H2 Electrolysis                                                     FR4 0
# GB2 0 H2 Electrolysis                                                     GB2 0
# GB5 0 H2 Electrolysis                                                     GB5 0
# IT0 0 H2 Electrolysis                                                     IT0 0
# IT3 0 H2 Electrolysis                                                     IT3 0
# LU0 0 H2 Electrolysis                                                     LU0 0
# NL0 0 H2 Electrolysis                                                     NL0 0
# NO1 0 H2 Electrolysis                                                     NO1 0
# PL0 0 H2 Electrolysis                                                     PL0 0
# SE1 0 H2 Electrolysis                                                     SE1 0
# AT0 0 H2 Fuel Cell                                                     AT0 0 H2
# BE0 0 H2 Fuel Cell                                                     BE0 0 H2
# CH0 0 H2 Fuel Cell                                                     CH0 0 H2
# CZ0 0 H2 Fuel Cell                                                     CZ0 0 H2
# DE0 0 H2 Fuel Cell                                                     DE0 0 H2
# DE0 1 H2 Fuel Cell                                                     DE0 1 H2
# DE0 2 H2 Fuel Cell                                                     DE0 2 H2
# DE0 3 H2 Fuel Cell                                                     DE0 3 H2
# DE0 4 H2 Fuel Cell                                                     DE0 4 H2
# DE0 5 H2 Fuel Cell                                                     DE0 5 H2
# DE0 6 H2 Fuel Cell                                                     DE0 6 H2
# DE0 7 H2 Fuel Cell                                                     DE0 7 H2
# DK0 0 H2 Fuel Cell                                                     DK0 0 H2
# DK1 0 H2 Fuel Cell                                                     DK1 0 H2
# ES0 0 H2 Fuel Cell                                                     ES0 0 H2
# ES6 0 H2 Fuel Cell                                                     ES6 0 H2
# FR0 0 H2 Fuel Cell                                                     FR0 0 H2
# FR4 0 H2 Fuel Cell                                                     FR4 0 H2
# GB2 0 H2 Fuel Cell                                                     GB2 0 H2
# GB5 0 H2 Fuel Cell                                                     GB5 0 H2
# IT0 0 H2 Fuel Cell                                                     IT0 0 H2
# IT3 0 H2 Fuel Cell                                                     IT3 0 H2
# LU0 0 H2 Fuel Cell                                                     LU0 0 H2
# NL0 0 H2 Fuel Cell                                                     NL0 0 H2
# NO1 0 H2 Fuel Cell                                                     NO1 0 H2
# PL0 0 H2 Fuel Cell                                                     PL0 0 H2
# SE1 0 H2 Fuel Cell                                                     SE1 0 H2
# H2 pipeline AT0 0 -> CH0 0                                             AT0 0 H2
# H2 pipeline AT0 0 -> CZ0 0                                             AT0 0 H2
# H2 pipeline AT0 0 -> DE0 3                                             AT0 0 H2
# H2 pipeline AT0 0 -> DE0 7                                             AT0 0 H2
# H2 pipeline AT0 0 -> IT0 0                                             AT0 0 H2
# H2 pipeline BE0 0 -> DE0 4                                             BE0 0 H2
# H2 pipeline BE0 0 -> FR0 0                                             BE0 0 H2
# H2 pipeline BE0 0 -> GB2 0                                             BE0 0 H2
# H2 pipeline BE0 0 -> LU0 0                                             BE0 0 H2
# H2 pipeline BE0 0 -> NL0 0                                             BE0 0 H2
# H2 pipeline CH0 0 -> DE0 3                                             CH0 0 H2
# H2 pipeline CH0 0 -> FR0 0                                             CH0 0 H2
# H2 pipeline CH0 0 -> IT0 0                                             CH0 0 H2
# H2 pipeline CZ0 0 -> DE0 6                                             CZ0 0 H2
# H2 pipeline CZ0 0 -> DE0 7                                             CZ0 0 H2
# H2 pipeline CZ0 0 -> PL0 0                                             CZ0 0 H2
# H2 pipeline DE0 0 -> DE0 1                                             DE0 0 H2
# H2 pipeline DE0 0 -> DE0 2                                             DE0 0 H2
# H2 pipeline DE0 0 -> DE0 3                                             DE0 0 H2
# H2 pipeline DE0 0 -> DE0 4                                             DE0 0 H2
# H2 pipeline DE0 0 -> DE0 5                                             DE0 0 H2
# H2 pipeline DE0 0 -> DE0 6                                             DE0 0 H2
# H2 pipeline DE0 0 -> DE0 7                                             DE0 0 H2
# H2 pipeline DE0 0 -> DK0 0                                             DE0 0 H2
# H2 pipeline DE0 0 -> DK1 0                                             DE0 0 H2
# H2 pipeline DE0 0 -> NO1 0                                             DE0 0 H2
# H2 pipeline DE0 0 -> SE1 0                                             DE0 0 H2
# H2 pipeline DE0 1 -> DE0 2                                             DE0 1 H2
# H2 pipeline DE0 1 -> DE0 3                                             DE0 1 H2
# H2 pipeline DE0 1 -> DE0 4                                             DE0 1 H2
# H2 pipeline DE0 1 -> DE0 5                                             DE0 1 H2
# H2 pipeline DE0 1 -> FR0 0                                             DE0 1 H2
# H2 pipeline DE0 2 -> DE0 3                                             DE0 2 H2
# H2 pipeline DE0 2 -> DE0 5                                             DE0 2 H2
# H2 pipeline DE0 2 -> DE0 6                                             DE0 2 H2
# H2 pipeline DE0 2 -> DE0 7                                             DE0 2 H2
# H2 pipeline DE0 3 -> DE0 7                                             DE0 3 H2
# H2 pipeline DE0 4 -> DE0 5                                             DE0 4 H2
# H2 pipeline DE0 4 -> FR0 0                                             DE0 4 H2
# H2 pipeline DE0 4 -> LU0 0                                             DE0 4 H2
# H2 pipeline DE0 4 -> NL0 0                                             DE0 4 H2
# H2 pipeline DE0 5 -> DE0 6                                             DE0 5 H2
# H2 pipeline DE0 5 -> GB2 0                                             DE0 5 H2
# H2 pipeline DE0 5 -> NL0 0                                             DE0 5 H2
# H2 pipeline DE0 6 -> PL0 0                                             DE0 6 H2
# H2 pipeline DK0 0 -> DK1 0                                             DK0 0 H2
# H2 pipeline DK0 0 -> GB2 0                                             DK0 0 H2
# H2 pipeline DK0 0 -> NL0 0                                             DK0 0 H2
# H2 pipeline DK0 0 -> NO1 0                                             DK0 0 H2
# H2 pipeline DK0 0 -> SE1 0                                             DK0 0 H2
# H2 pipeline DK1 0 -> SE1 0                                             DK1 0 H2
# H2 pipeline ES0 0 -> ES6 0                                             ES0 0 H2
# H2 pipeline ES0 0 -> FR0 0                                             ES0 0 H2
# H2 pipeline FR0 0 -> GB2 0                                             FR0 0 H2
# H2 pipeline FR0 0 -> IT0 0                                             FR0 0 H2
# H2 pipeline FR0 0 -> LU0 0                                             FR0 0 H2
# H2 pipeline FR4 0 -> IT0 0                                             FR4 0 H2
# H2 pipeline FR4 0 -> IT3 0                                             FR4 0 H2
# H2 pipeline GB2 0 -> GB5 0                                             GB2 0 H2
# H2 pipeline GB2 0 -> NL0 0                                             GB2 0 H2
# H2 pipeline GB2 0 -> NO1 0                                             GB2 0 H2
# H2 pipeline IT0 0 -> IT3 0                                             IT0 0 H2
# H2 pipeline NL0 0 -> NO1 0                                             NL0 0 H2
# H2 pipeline NO1 0 -> SE1 0                                             NO1 0 H2
# H2 pipeline PL0 0 -> SE1 0                                             PL0 0 H2
# AT0 0 battery charger                                                     AT0 0
# BE0 0 battery charger                                                     BE0 0
# CH0 0 battery charger                                                     CH0 0
# CZ0 0 battery charger                                                     CZ0 0
# DE0 0 battery charger                                                     DE0 0
# DE0 1 battery charger                                                     DE0 1
# DE0 2 battery charger                                                     DE0 2
# DE0 3 battery charger                                                     DE0 3
# DE0 4 battery charger                                                     DE0 4
# DE0 5 battery charger                                                     DE0 5
# DE0 6 battery charger                                                     DE0 6
# DE0 7 battery charger                                                     DE0 7
# DK0 0 battery charger                                                     DK0 0
# DK1 0 battery charger                                                     DK1 0
# ES0 0 battery charger                                                     ES0 0
# ES6 0 battery charger                                                     ES6 0
# FR0 0 battery charger                                                     FR0 0
# FR4 0 battery charger                                                     FR4 0
# GB2 0 battery charger                                                     GB2 0
# GB5 0 battery charger                                                     GB5 0
# IT0 0 battery charger                                                     IT0 0
# IT3 0 battery charger                                                     IT3 0
# LU0 0 battery charger                                                     LU0 0
# NL0 0 battery charger                                                     NL0 0
# NO1 0 battery charger                                                     NO1 0
# PL0 0 battery charger                                                     PL0 0
# SE1 0 battery charger                                                     SE1 0
# AT0 0 battery discharger                                          AT0 0 battery
# BE0 0 battery discharger                                          BE0 0 battery
# CH0 0 battery discharger                                          CH0 0 battery
# CZ0 0 battery discharger                                          CZ0 0 battery
# DE0 0 battery discharger                                          DE0 0 battery
# DE0 1 battery discharger                                          DE0 1 battery
# DE0 2 battery discharger                                          DE0 2 battery
# DE0 3 battery discharger                                          DE0 3 battery
# DE0 4 battery discharger                                          DE0 4 battery
# DE0 5 battery discharger                                          DE0 5 battery
# DE0 6 battery discharger                                          DE0 6 battery
# DE0 7 battery discharger                                          DE0 7 battery
# DK0 0 battery discharger                                          DK0 0 battery
# DK1 0 battery discharger                                          DK1 0 battery
# ES0 0 battery discharger                                          ES0 0 battery
# ES6 0 battery discharger                                          ES6 0 battery
# FR0 0 battery discharger                                          FR0 0 battery
# FR4 0 battery discharger                                          FR4 0 battery
# GB2 0 battery discharger                                          GB2 0 battery
# GB5 0 battery discharger                                          GB5 0 battery
# IT0 0 battery discharger                                          IT0 0 battery
# IT3 0 battery discharger                                          IT3 0 battery
# LU0 0 battery discharger                                          LU0 0 battery
# NL0 0 battery discharger                                          NL0 0 battery
# NO1 0 battery discharger                                          NO1 0 battery
# PL0 0 battery discharger                                          PL0 0 battery
# SE1 0 battery discharger                                          SE1 0 battery
# AT0 0 Sabatier                                                         AT0 0 H2
# BE0 0 Sabatier                                                         BE0 0 H2
# CH0 0 Sabatier                                                         CH0 0 H2
# CZ0 0 Sabatier                                                         CZ0 0 H2
# DE0 0 Sabatier                                                         DE0 0 H2
# DE0 1 Sabatier                                                         DE0 1 H2
# DE0 2 Sabatier                                                         DE0 2 H2
# DE0 3 Sabatier                                                         DE0 3 H2
# DE0 4 Sabatier                                                         DE0 4 H2
# DE0 5 Sabatier                                                         DE0 5 H2
# DE0 6 Sabatier                                                         DE0 6 H2
# DE0 7 Sabatier                                                         DE0 7 H2
# DK0 0 Sabatier                                                         DK0 0 H2
# DK1 0 Sabatier                                                         DK1 0 H2
# ES0 0 Sabatier                                                         ES0 0 H2
# ES6 0 Sabatier                                                         ES6 0 H2
# FR0 0 Sabatier                                                         FR0 0 H2
# FR4 0 Sabatier                                                         FR4 0 H2
# GB2 0 Sabatier                                                         GB2 0 H2
# GB5 0 Sabatier                                                         GB5 0 H2
# IT0 0 Sabatier                                                         IT0 0 H2
# IT3 0 Sabatier                                                         IT3 0 H2
# LU0 0 Sabatier                                                         LU0 0 H2
# NL0 0 Sabatier                                                         NL0 0 H2
# NO1 0 Sabatier                                                         NO1 0 H2
# PL0 0 Sabatier                                                         PL0 0 H2
# SE1 0 Sabatier                                                         SE1 0 H2
# AT0 0 SMR CC                                                             EU gas
# BE0 0 SMR CC                                                             EU gas
# CH0 0 SMR CC                                                             EU gas
# CZ0 0 SMR CC                                                             EU gas
# DE0 0 SMR CC                                                             EU gas
# DE0 1 SMR CC                                                             EU gas
# DE0 2 SMR CC                                                             EU gas
# DE0 3 SMR CC                                                             EU gas
# DE0 4 SMR CC                                                             EU gas
# DE0 5 SMR CC                                                             EU gas
# DE0 6 SMR CC                                                             EU gas
# DE0 7 SMR CC                                                             EU gas
# DK0 0 SMR CC                                                             EU gas
# DK1 0 SMR CC                                                             EU gas
# ES0 0 SMR CC                                                             EU gas
# ES6 0 SMR CC                                                             EU gas
# FR0 0 SMR CC                                                             EU gas
# FR4 0 SMR CC                                                             EU gas
# GB2 0 SMR CC                                                             EU gas
# GB5 0 SMR CC                                                             EU gas
# IT0 0 SMR CC                                                             EU gas
# IT3 0 SMR CC                                                             EU gas
# LU0 0 SMR CC                                                             EU gas
# NL0 0 SMR CC                                                             EU gas
# NO1 0 SMR CC                                                             EU gas
# PL0 0 SMR CC                                                             EU gas
# SE1 0 SMR CC                                                             EU gas
# AT0 0 SMR                                                                EU gas
# BE0 0 SMR                                                                EU gas
# CH0 0 SMR                                                                EU gas
# CZ0 0 SMR                                                                EU gas
# DE0 0 SMR                                                                EU gas
# DE0 1 SMR                                                                EU gas
# DE0 2 SMR                                                                EU gas
# DE0 3 SMR                                                                EU gas
# DE0 4 SMR                                                                EU gas
# DE0 5 SMR                                                                EU gas
# DE0 6 SMR                                                                EU gas
# DE0 7 SMR                                                                EU gas
# DK0 0 SMR                                                                EU gas
# DK1 0 SMR                                                                EU gas
# ES0 0 SMR                                                                EU gas
# ES6 0 SMR                                                                EU gas
# FR0 0 SMR                                                                EU gas
# FR4 0 SMR                                                                EU gas
# GB2 0 SMR                                                                EU gas
# GB5 0 SMR                                                                EU gas
# IT0 0 SMR                                                                EU gas
# IT3 0 SMR                                                                EU gas
# LU0 0 SMR                                                                EU gas
# NL0 0 SMR                                                                EU gas
# NO1 0 SMR                                                                EU gas
# PL0 0 SMR                                                                EU gas
# SE1 0 SMR                                                                EU gas
# AT0 0 BEV charger                                             AT0 0 low voltage
# BE0 0 BEV charger                                             BE0 0 low voltage
# CH0 0 BEV charger                                             CH0 0 low voltage
# CZ0 0 BEV charger                                             CZ0 0 low voltage
# DE0 0 BEV charger                                             DE0 0 low voltage
# DE0 1 BEV charger                                             DE0 1 low voltage
# DE0 2 BEV charger                                             DE0 2 low voltage
# DE0 3 BEV charger                                             DE0 3 low voltage
# DE0 4 BEV charger                                             DE0 4 low voltage
# DE0 5 BEV charger                                             DE0 5 low voltage
# DE0 6 BEV charger                                             DE0 6 low voltage
# DE0 7 BEV charger                                             DE0 7 low voltage
# DK0 0 BEV charger                                             DK0 0 low voltage
# DK1 0 BEV charger                                             DK1 0 low voltage
# ES0 0 BEV charger                                             ES0 0 low voltage
# ES6 0 BEV charger                                             ES6 0 low voltage
# FR0 0 BEV charger                                             FR0 0 low voltage
# FR4 0 BEV charger                                             FR4 0 low voltage
# GB2 0 BEV charger                                             GB2 0 low voltage
# GB5 0 BEV charger                                             GB5 0 low voltage
# IT0 0 BEV charger                                             IT0 0 low voltage
# IT3 0 BEV charger                                             IT3 0 low voltage
# LU0 0 BEV charger                                             LU0 0 low voltage
# NL0 0 BEV charger                                             NL0 0 low voltage
# NO1 0 BEV charger                                             NO1 0 low voltage
# PL0 0 BEV charger                                             PL0 0 low voltage
# SE1 0 BEV charger                                             SE1 0 low voltage
# AT0 0 V2G                                                      AT0 0 EV battery
# BE0 0 V2G                                                      BE0 0 EV battery
# CH0 0 V2G                                                      CH0 0 EV battery
# CZ0 0 V2G                                                      CZ0 0 EV battery
# DE0 0 V2G                                                      DE0 0 EV battery
# DE0 1 V2G                                                      DE0 1 EV battery
# DE0 2 V2G                                                      DE0 2 EV battery
# DE0 3 V2G                                                      DE0 3 EV battery
# DE0 4 V2G                                                      DE0 4 EV battery
# DE0 5 V2G                                                      DE0 5 EV battery
# DE0 6 V2G                                                      DE0 6 EV battery
# DE0 7 V2G                                                      DE0 7 EV battery
# DK0 0 V2G                                                      DK0 0 EV battery
# DK1 0 V2G                                                      DK1 0 EV battery
# ES0 0 V2G                                                      ES0 0 EV battery
# ES6 0 V2G                                                      ES6 0 EV battery
# FR0 0 V2G                                                      FR0 0 EV battery
# FR4 0 V2G                                                      FR4 0 EV battery
# GB2 0 V2G                                                      GB2 0 EV battery
# GB5 0 V2G                                                      GB5 0 EV battery
# IT0 0 V2G                                                      IT0 0 EV battery
# IT3 0 V2G                                                      IT3 0 EV battery
# LU0 0 V2G                                                      LU0 0 EV battery
# NL0 0 V2G                                                      NL0 0 EV battery
# NO1 0 V2G                                                      NO1 0 EV battery
# PL0 0 V2G                                                      PL0 0 EV battery
# SE1 0 V2G                                                      SE1 0 EV battery
# EU oil refining                                                  EU oil primary
# EU land transport oil                                                    EU oil
# AT0 0 urban central air heat pump                             AT0 0 low voltage
# BE0 0 urban central air heat pump                             BE0 0 low voltage
# CH0 0 urban central air heat pump                             CH0 0 low voltage
# CZ0 0 urban central air heat pump                             CZ0 0 low voltage
# DE0 0 urban central air heat pump                             DE0 0 low voltage
# DE0 1 urban central air heat pump                             DE0 1 low voltage
# DE0 2 urban central air heat pump                             DE0 2 low voltage
# DE0 3 urban central air heat pump                             DE0 3 low voltage
# DE0 4 urban central air heat pump                             DE0 4 low voltage
# DE0 5 urban central air heat pump                             DE0 5 low voltage
# DE0 6 urban central air heat pump                             DE0 6 low voltage
# DE0 7 urban central air heat pump                             DE0 7 low voltage
# DK0 0 urban central air heat pump                             DK0 0 low voltage
# DK1 0 urban central air heat pump                             DK1 0 low voltage
# ES0 0 urban central air heat pump                             ES0 0 low voltage
# ES6 0 urban central air heat pump                             ES6 0 low voltage
# FR0 0 urban central air heat pump                             FR0 0 low voltage
# GB2 0 urban central air heat pump                             GB2 0 low voltage
# GB5 0 urban central air heat pump                             GB5 0 low voltage
# IT0 0 urban central air heat pump                             IT0 0 low voltage
# LU0 0 urban central air heat pump                             LU0 0 low voltage
# NL0 0 urban central air heat pump                             NL0 0 low voltage
# NO1 0 urban central air heat pump                             NO1 0 low voltage
# PL0 0 urban central air heat pump                             PL0 0 low voltage
# SE1 0 urban central air heat pump                             SE1 0 low voltage
# AT0 0 urban central water tanks charger                AT0 0 urban central heat
# BE0 0 urban central water tanks charger                BE0 0 urban central heat
# CH0 0 urban central water tanks charger                CH0 0 urban central heat
# CZ0 0 urban central water tanks charger                CZ0 0 urban central heat
# DE0 0 urban central water tanks charger                DE0 0 urban central heat
# DE0 1 urban central water tanks charger                DE0 1 urban central heat
# DE0 2 urban central water tanks charger                DE0 2 urban central heat
# DE0 3 urban central water tanks charger                DE0 3 urban central heat
# DE0 4 urban central water tanks charger                DE0 4 urban central heat
# DE0 5 urban central water tanks charger                DE0 5 urban central heat
# DE0 6 urban central water tanks charger                DE0 6 urban central heat
# DE0 7 urban central water tanks charger                DE0 7 urban central heat
# DK0 0 urban central water tanks charger                DK0 0 urban central heat
# DK1 0 urban central water tanks charger                DK1 0 urban central heat
# ES0 0 urban central water tanks charger                ES0 0 urban central heat
# ES6 0 urban central water tanks charger                ES6 0 urban central heat
# FR0 0 urban central water tanks charger                FR0 0 urban central heat
# GB2 0 urban central water tanks charger                GB2 0 urban central heat
# GB5 0 urban central water tanks charger                GB5 0 urban central heat
# IT0 0 urban central water tanks charger                IT0 0 urban central heat
# LU0 0 urban central water tanks charger                LU0 0 urban central heat
# NL0 0 urban central water tanks charger                NL0 0 urban central heat
# NO1 0 urban central water tanks charger                NO1 0 urban central heat
# PL0 0 urban central water tanks charger                PL0 0 urban central heat
# SE1 0 urban central water tanks charger                SE1 0 urban central heat
# AT0 0 urban central water tanks discharger      AT0 0 urban central water tanks
# BE0 0 urban central water tanks discharger      BE0 0 urban central water tanks
# CH0 0 urban central water tanks discharger      CH0 0 urban central water tanks
# CZ0 0 urban central water tanks discharger      CZ0 0 urban central water tanks
# DE0 0 urban central water tanks discharger      DE0 0 urban central water tanks
# DE0 1 urban central water tanks discharger      DE0 1 urban central water tanks
# DE0 2 urban central water tanks discharger      DE0 2 urban central water tanks
# DE0 3 urban central water tanks discharger      DE0 3 urban central water tanks
# DE0 4 urban central water tanks discharger      DE0 4 urban central water tanks
# DE0 5 urban central water tanks discharger      DE0 5 urban central water tanks
# DE0 6 urban central water tanks discharger      DE0 6 urban central water tanks
# DE0 7 urban central water tanks discharger      DE0 7 urban central water tanks
# DK0 0 urban central water tanks discharger      DK0 0 urban central water tanks
# DK1 0 urban central water tanks discharger      DK1 0 urban central water tanks
# ES0 0 urban central water tanks discharger      ES0 0 urban central water tanks
# ES6 0 urban central water tanks discharger      ES6 0 urban central water tanks
# FR0 0 urban central water tanks discharger      FR0 0 urban central water tanks
# GB2 0 urban central water tanks discharger      GB2 0 urban central water tanks
# GB5 0 urban central water tanks discharger      GB5 0 urban central water tanks
# IT0 0 urban central water tanks discharger      IT0 0 urban central water tanks
# LU0 0 urban central water tanks discharger      LU0 0 urban central water tanks
# NL0 0 urban central water tanks discharger      NL0 0 urban central water tanks
# NO1 0 urban central water tanks discharger      NO1 0 urban central water tanks
# PL0 0 urban central water tanks discharger      PL0 0 urban central water tanks
# SE1 0 urban central water tanks discharger      SE1 0 urban central water tanks
# AT0 0 urban central resistive heater                          AT0 0 low voltage
# BE0 0 urban central resistive heater                          BE0 0 low voltage
# CH0 0 urban central resistive heater                          CH0 0 low voltage
# CZ0 0 urban central resistive heater                          CZ0 0 low voltage
# DE0 0 urban central resistive heater                          DE0 0 low voltage
# DE0 1 urban central resistive heater                          DE0 1 low voltage
# DE0 2 urban central resistive heater                          DE0 2 low voltage
# DE0 3 urban central resistive heater                          DE0 3 low voltage
# DE0 4 urban central resistive heater                          DE0 4 low voltage
# DE0 5 urban central resistive heater                          DE0 5 low voltage
# DE0 6 urban central resistive heater                          DE0 6 low voltage
# DE0 7 urban central resistive heater                          DE0 7 low voltage
# DK0 0 urban central resistive heater                          DK0 0 low voltage
# DK1 0 urban central resistive heater                          DK1 0 low voltage
# ES0 0 urban central resistive heater                          ES0 0 low voltage
# ES6 0 urban central resistive heater                          ES6 0 low voltage
# FR0 0 urban central resistive heater                          FR0 0 low voltage
# GB2 0 urban central resistive heater                          GB2 0 low voltage
# GB5 0 urban central resistive heater                          GB5 0 low voltage
# IT0 0 urban central resistive heater                          IT0 0 low voltage
# LU0 0 urban central resistive heater                          LU0 0 low voltage
# NL0 0 urban central resistive heater                          NL0 0 low voltage
# NO1 0 urban central resistive heater                          NO1 0 low voltage
# PL0 0 urban central resistive heater                          PL0 0 low voltage
# SE1 0 urban central resistive heater                          SE1 0 low voltage
# AT0 0 urban central gas boiler                                           EU gas
# BE0 0 urban central gas boiler                                           EU gas
# CH0 0 urban central gas boiler                                           EU gas
# CZ0 0 urban central gas boiler                                           EU gas
# DE0 0 urban central gas boiler                                           EU gas
# DE0 1 urban central gas boiler                                           EU gas
# DE0 2 urban central gas boiler                                           EU gas
# DE0 3 urban central gas boiler                                           EU gas
# DE0 4 urban central gas boiler                                           EU gas
# DE0 5 urban central gas boiler                                           EU gas
# DE0 6 urban central gas boiler                                           EU gas
# DE0 7 urban central gas boiler                                           EU gas
# DK0 0 urban central gas boiler                                           EU gas
# DK1 0 urban central gas boiler                                           EU gas
# ES0 0 urban central gas boiler                                           EU gas
# ES6 0 urban central gas boiler                                           EU gas
# FR0 0 urban central gas boiler                                           EU gas
# GB2 0 urban central gas boiler                                           EU gas
# GB5 0 urban central gas boiler                                           EU gas
# IT0 0 urban central gas boiler                                           EU gas
# LU0 0 urban central gas boiler                                           EU gas
# NL0 0 urban central gas boiler                                           EU gas
# NO1 0 urban central gas boiler                                           EU gas
# PL0 0 urban central gas boiler                                           EU gas
# SE1 0 urban central gas boiler                                           EU gas
# AT0 0 urban central gas CHP                                              EU gas
# BE0 0 urban central gas CHP                                              EU gas
# CH0 0 urban central gas CHP                                              EU gas
# CZ0 0 urban central gas CHP                                              EU gas
# DE0 0 urban central gas CHP                                              EU gas
# DE0 1 urban central gas CHP                                              EU gas
# DE0 2 urban central gas CHP                                              EU gas
# DE0 3 urban central gas CHP                                              EU gas
# DE0 4 urban central gas CHP                                              EU gas
# DE0 5 urban central gas CHP                                              EU gas
# DE0 6 urban central gas CHP                                              EU gas
# DE0 7 urban central gas CHP                                              EU gas
# DK0 0 urban central gas CHP                                              EU gas
# DK1 0 urban central gas CHP                                              EU gas
# ES0 0 urban central gas CHP                                              EU gas
# ES6 0 urban central gas CHP                                              EU gas
# FR0 0 urban central gas CHP                                              EU gas
# GB2 0 urban central gas CHP                                              EU gas
# GB5 0 urban central gas CHP                                              EU gas
# IT0 0 urban central gas CHP                                              EU gas
# LU0 0 urban central gas CHP                                              EU gas
# NL0 0 urban central gas CHP                                              EU gas
# NO1 0 urban central gas CHP                                              EU gas
# PL0 0 urban central gas CHP                                              EU gas
# SE1 0 urban central gas CHP                                              EU gas
# AT0 0 urban central gas CHP CC                                           EU gas
# BE0 0 urban central gas CHP CC                                           EU gas
# CH0 0 urban central gas CHP CC                                           EU gas
# CZ0 0 urban central gas CHP CC                                           EU gas
# DE0 0 urban central gas CHP CC                                           EU gas
# DE0 1 urban central gas CHP CC                                           EU gas
# DE0 2 urban central gas CHP CC                                           EU gas
# DE0 3 urban central gas CHP CC                                           EU gas
# DE0 4 urban central gas CHP CC                                           EU gas
# DE0 5 urban central gas CHP CC                                           EU gas
# DE0 6 urban central gas CHP CC                                           EU gas
# DE0 7 urban central gas CHP CC                                           EU gas
# DK0 0 urban central gas CHP CC                                           EU gas
# DK1 0 urban central gas CHP CC                                           EU gas
# ES0 0 urban central gas CHP CC                                           EU gas
# ES6 0 urban central gas CHP CC                                           EU gas
# FR0 0 urban central gas CHP CC                                           EU gas
# GB2 0 urban central gas CHP CC                                           EU gas
# GB5 0 urban central gas CHP CC                                           EU gas
# IT0 0 urban central gas CHP CC                                           EU gas
# LU0 0 urban central gas CHP CC                                           EU gas
# NL0 0 urban central gas CHP CC                                           EU gas
# NO1 0 urban central gas CHP CC                                           EU gas
# PL0 0 urban central gas CHP CC                                           EU gas
# SE1 0 urban central gas CHP CC                                           EU gas
# EU biogas to gas                                                      EU biogas
# AT0 0 urban central solid biomass CHP                          EU solid biomass
# BE0 0 urban central solid biomass CHP                          EU solid biomass
# CH0 0 urban central solid biomass CHP                          EU solid biomass
# CZ0 0 urban central solid biomass CHP                          EU solid biomass
# DE0 0 urban central solid biomass CHP                          EU solid biomass
# ...
# LU0 0 geothermal reservoir         0.0000  0.0000     0.0000     LU0 0
# NL0 0 geothermal reservoir         0.0000  0.0000     0.0000     NL0 0
# NO1 0 geothermal reservoir         0.0000  0.0000     0.0000     NO1 0
# PL0 0 geothermal reservoir         0.0000  0.0000     0.0000     PL0 0
# SE1 0 geothermal reservoir         0.0000  0.0000     0.0000     SE1 0
#
# [61 rows x 34 columns]
# cluster                                                                      27
# ll                                                                         vopt
# opt                                                                        3H3H
# planning_horizon                                                           2045
# generators    capital  biogas                                            0.0000
#                        coal                                              0.0000
#                        gas                                               0.0000
#                        geothermal heat                                   0.0000
#                        nuclear                                 74158195641.9979
#                        offwind-ac                               3991606617.8404
#                        offwind-dc                               2958314284.2359
#                        offwind-float                            1388982829.4892
#                        oil primary                                       0.0000
#                        onwind                                 166969445307.3546
#                        ror                                      9999550786.9411
#                        rural solar thermal                            2894.2045
#                        solar                                    7604372371.2376
#                        solar rooftop                            2702715883.0196
#                        solar-hsat                              10724503137.0049
#                        solid biomass                                     0.0000
#                        urban central solar thermal                    3128.8411
#                        urban decentral solar thermal                  3158.4471
#               marginal biogas                                  17668269817.1683
#                        coal                                      237777630.6000
#                        gas                                      1145388101.5695
#                        geothermal heat                                   0.2599
#                        nuclear                                  6790347433.6519
#                        offwind-ac                                  1969612.3616
#                        offwind-dc                                   987281.4681
#                        offwind-float                                293595.7109
#                        oil primary                             15124183296.0841
#                        onwind                                    139874914.2060
#                        ror                                         1156901.3800
#                        rural solar thermal                               0.2765
#                        solar                                       2160728.7728
#                        solar rooftop                               1043957.0554
#                        solar-hsat                                  5645269.2700
#                        solid biomass                           10107248724.3130
#                        urban central solar thermal                       0.6525
#                        urban decentral solar thermal                     0.3296
# lines         capital  AC                                       5316765462.1147
# links         capital  BEV charger                                       0.0000
#                        DAC                                     29060694731.6274
#                        DC                                      15857427743.9546
#                        Fischer-Tropsch                         14484713077.2441
#                        H2 Electrolysis                        108610791364.7393
#                        H2 Fuel Cell                                   3937.1111
#                        H2 pipeline                              1167178983.8157
#                        OCGT                                           4626.0413
#                        SMR                                            4580.8623
#                        SMR CC                                         5594.4890
#                        Sabatier                                       3116.5271
#                        V2G                                               0.0000
#                        agriculture machinery oil                         0.0000
#                        battery charger                               10450.1209
#                        battery discharger                                0.0000
#                        biogas to gas                            7860187890.5345
#                        co2 sequestered                                   0.0000
#                        coal for industry                                 0.0000
#                        electricity distribution grid           27074113477.6865
#                        gas for industry                                  0.0000
#                        gas for industry CC                      2223488967.9385
#                        geothermal district heat                       3393.7034
#                        geothermal heat                              103451.2276
#                        geothermal organic rankine cycle               4820.4032
#                        home battery charger                          10827.4172
#                        home battery discharger                           0.0000
#                        industry methanol                                 0.0000
#                        kerosene for aviation                             0.0000
#                        land transport oil                                0.0000
#                        methanolisation                          5352705638.1324
#                        naphtha for industry                              0.0000
#                        oil refining                                      0.0000
#                        process emissions                                 0.0000
#                        process emissions CC                     4496462394.6259
#                        rural air heat pump                           23896.2441
#                        rural biomass boiler                     1058084161.0726
#                        rural gas boiler                          319197252.6954
#                        rural ground heat pump                  18867944684.9134
#                        rural resistive heater                    655553330.7554
#                        rural water tanks charger                         0.0000
#                        rural water tanks discharger                      0.0000
#                        shipping methanol                                 0.0000
#                        shipping oil                                      0.0000
#                        solid biomass for industry                        0.0000
#                        solid biomass for industry CC            8468161881.3945
#                        urban central CHP                         393678966.5958
#                        urban central CHP CC                           4412.5686
#                        urban central air heat pump             15988063730.3134
#                        urban central gas boiler                  632991091.4149
#                        urban central resistive heater            739630338.3011
#                        urban central solid biomass CHP                9440.2876
#                        urban central solid biomass CHP CC       1922431156.4422
#                        urban central water tanks charger                 0.0000
#                        urban central water tanks discharger              0.0000
#                        urban decentral air heat pump           19947703344.6027
#                        urban decentral biomass boiler           5022350790.3048
#                        urban decentral gas boiler                189158005.5298
#                        urban decentral resistive heater         1610701357.1306
#                        urban decentral water tanks charger               0.0000
#                        urban decentral water tanks discharger            0.0000
#               marginal BEV charger                                 8055998.1731
#                        DAC                                         1371089.7655
#                        DC                                         11351545.4011
#                        Fischer-Tropsch                          6583600873.0909
#                        H2 Electrolysis                            37168691.8578
#                        H2 Fuel Cell                                      0.4083
#                        H2 pipeline                                 4510314.4675
#                        OCGT                                            110.2917
#                        SMR                                               0.9184
#                        SMR CC                                            1.4734
#                        Sabatier                                          1.9710
#                        V2G                                          356293.2829
#                        agriculture machinery oil                    827541.4988
#                        battery charger                                  14.8207
#                        battery discharger                               14.4226
#                        biogas to gas                            1254740848.6779
#                        co2 sequestered                             1816363.1172
#                        coal for industry                            262338.3435
#                        electricity distribution grid              29376949.4322
#                        gas for industry                                  0.1222
#                        gas for industry CC                         3232566.7289
#                        geothermal district heat                          0.1460
#                        geothermal heat                                   0.2414
#                        geothermal organic rankine cycle                  0.0937
#                        home battery charger                             10.2754
#                        home battery discharger                           9.9287
#                        industry methanol                             75530.9288
#                        kerosene for aviation                       6481365.4587
#                        land transport oil                          3905396.5946
#                        methanolisation                             4081510.1435
#                        naphtha for industry                        3757151.2668
#                        oil refining                                2878004.3388
#                        process emissions                                 0.0128
#                        process emissions CC                        1317727.3208
#                        rural air heat pump                               2.7076
#                        rural biomass boiler                       75977576.1754
#                        rural gas boiler                               8392.6088
#                        rural ground heat pump                      1682772.3680
#                        rural resistive heater                       367223.9675
#                        rural water tanks charger                    224584.4086
#                        rural water tanks discharger                 197885.8899
#                        shipping methanol                           3444278.3119
#                        shipping oil                                 684296.6818
#                        solid biomass for industry                        0.0383
#                        solid biomass for industry CC               5816812.1989
#                        urban central CHP                          11317258.5466
#                        urban central CHP CC                            228.1476
#                        urban central air heat pump                 2725580.3839
#                        urban central gas boiler                     219551.2902
#                        urban central resistive heater              1208842.0952
#                        urban central solid biomass CHP                 931.5788
#                        urban central solid biomass CHP CC        242317150.5760
#                        urban central water tanks charger           8134415.0129
#                        urban central water tanks discharger        7906511.2046
#                        urban decentral air heat pump               2739512.8929
#                        urban decentral biomass boiler            521793517.7770
#                        urban decentral gas boiler                     5130.2588
#                        urban decentral resistive heater            1486323.7837
#                        urban decentral water tanks charger          610937.4206
#                        urban decentral water tanks discharger       513348.9552
# storage_units capital  PHS                                      8676421369.3621
#                        geothermal heat                                   0.0000
#                        hydro                                   15450047146.8764
#               marginal PHS                                          612604.5302
#                        geothermal heat                                   0.0001
#                        hydro                                       2658733.1405
# stores        capital  EV battery                                        0.0000
#                        H2 Store                                 1051701570.0100
#                        battery                                        7314.4083
#                        co2                                               0.0000
#                        co2 sequestered                          2000000000.0547
#                        co2 stored                                      145.9462
#                        coal                                       26364425.0343
#                        gas                                             154.0528
#                        home battery                                   6620.6242
#                        methanol                                  110543402.0779
#                        oil                                          257152.3854
#                        rural water tanks                         281734813.8791
#                        urban central water tanks                3959439780.7549
#                        urban decentral water tanks               542348468.9427
#               marginal EV battery                                        0.0000
#                        H2 Store                                          0.0000
#                        battery                                           0.0000
#                        co2                                              -0.0000
#                        co2 sequestered                            17898081.1674
#                        co2 stored                                        0.0000
#                        coal                                             -0.0000
#                        gas                                               0.0000
#                        home battery                                      0.0000
#                        methanol                                         -0.0000
#                        oil                                               0.0000
#                        rural water tanks                            -25589.9297
#                        urban central water tanks                   -144934.0938
#                        urban decentral water tanks                  -80141.5127
