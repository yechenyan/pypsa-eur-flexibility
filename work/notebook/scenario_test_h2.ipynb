# %%
import pypsa
import matplotlib.pyplot as plt
import pandas as pd


rootPath = "../../results/scenario/battery"


plt.style.use('bmh')
# %matplotlib inline

n = pypsa.Network("../../results/scenario/h2-best/postnetworks/base_s_27_lvopt_3H_3H_2045.nc")
# Out:
# INFO:pypsa.io:Imported network base_s_27_lvopt_3H_3H_2045.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
import myUtils as utils

import importlib
importlib.reload(utils)

ids = utils.de_h2_turbine_grouper(n, 'Link').tolist()

# %%
ids = utils.de_h2_load_grouper(n, 'Load').tolist()
n.loads_t.p[ids].plot()
# Out:
# <Axes: xlabel='snapshot'>
